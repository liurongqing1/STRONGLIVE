# %%
# numpy和panda用于数据操作
import numpy as np
import pandas as pd

df = pd.read_csv("F:/video_cut/Bear_size.csv") 

df=df[ ['keypoint', 'brightness', 'contrast','edgeLength',
        'Hue1','Hue2','Hue3','Hue4',	'Hue5',	'Hue6',	'Hue7',
        'Saturation','Value','TI','SI',"first_frame"]]

#data = pd.read_csv("C:/Users/aqing/Desktop/dog/dog.csv") 
data = pd.read_csv("E:/研学/桌面移动数据/dog/dog.csv") 

data = data[['keypoint', 'brightness', 'contrast','edgeLength',
             'Hue1','Hue2', 'Hue3','Hue4',	'Hue5',	'Hue6',	'Hue7',
             'Saturation','Value','TI','SI', "first_frame"]]
##patch = pd.read_excel("J:/edge_dection/feature_test.xlsx")
'''
patch = patch[['keypoint','brightness','contrast','edgeLength',
       'Hue1','Hue2','Hue3','Hue4',	'Hue5',	'Hue6',	'Hue7',	
       'Saturation','Value']]
patch = patch[['keypoint','brightness','contrast','edgeLength',
               'Hue1','Hue2','Hue3','Hue4',	'Hue5',	'Hue6',	'Hue7',	
               'Saturation','Value','TI','SI', "first_frame"]]
'''
print(data)
print(df)
##print(patch)
# Out:
#           keypoint  brightness   contrast    edgeLength       Hue1       Hue2  \
# 0      9581.333333   88.814420  39.272862     203.96547  22.909090  12.743542
# 1      9581.333333   88.814420  39.272862     203.96547  22.909090  12.743542
# 2      9581.333333   88.814420  39.272862     203.96547  22.909090  12.743542
# 3      9581.333333   88.814420  39.272862     203.96547  22.909090  12.743542
# 4      9581.333333   88.814420  39.272862     203.96547  22.909090  12.743542
# ...            ...         ...        ...           ...        ...        ...
# 3010  72865.200000  127.507687  66.088593  726908.75730  58.987355  54.904391
# 3011  72865.200000  127.507687  66.088593  726908.75730  58.987355  54.904391
# 3012  72865.200000  127.507687  66.088593  726908.75730  58.987355  54.904391
# 3013  72865.200000  127.507687  66.088593  726908.75730  58.987355  54.904391
# 3014  72865.200000  127.507687  66.088593  726908.75730  58.987355  54.904391
#
# ...

# %%
A = df.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(font_scale=1.5)
plt.rcParams['font.sans-serif']=['SimHei']  # 用于显示中文
plt.rcParams['axes.unicode_minus'] = False  # 用于显示中文
sns.set_context({"figure.figsize":(16,16)})
fig = sns.heatmap(data=A,annot=True,fmt=".2f",
                  cmap=sns.diverging_palette(10, 220, sep=80, n=7),
                  linewidths=0.3)
heatmap = fig.get_figure()
#heatmap.savefig("E:/研学/绘图/me/fps_hotmap.png", dpi = 400)

# %%
B = data.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(font_scale=1.5)
plt.rcParams['font.sans-serif']=['SimHei']  # 用于显示中文
plt.rcParams['axes.unicode_minus'] = False  # 用于显示中文
sns.set_context({"figure.figsize":(16,16)})
fig = sns.heatmap(data=B,annot=True,fmt=".2f",
                  cmap=sns.diverging_palette(10, 220, sep=80, n=7),
                  linewidths=0.3)
heatmap = fig.get_figure()
heatmap.savefig("E:/研学/绘图/me/vmaf_hotmap.png", dpi = 400)

# %%
C = patch.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(font_scale=1.5)
plt.rcParams['font.sans-serif']=['SimHei']  # 用于显示中文
plt.rcParams['axes.unicode_minus'] = False  # 用于显示中文
sns.set_context({"figure.figsize":(16,16)})
fig = sns.heatmap(data=C,annot=True,fmt=".2f",
                  cmap=sns.diverging_palette(10, 220, sep=80, n=7),
                  linewidths=0.3)
heatmap = fig.get_figure()
heatmap.savefig("E:/研学/绘图/me/patch_hotmap2.pdf", dpi = 400)
