# %%
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()

# A =np.array([[2,11,9,3,0,1,14,14,15,7,2,0,6,7,3,2,0,2,2],
# [0,0,3,1,0,0,7,10,12,5,1,0,9,14,9,8,3,8,10],
# [0,0,2,0,0,0,6,9,12,3,0,0,12,18,15,5,2,7,9],
# [0,0,0,0,0,0,5,10,13,2,0,0,15,17,16,3,2,0,17],
# [0,0,3,0,1,0,13,19,17,7,0,0,13,14,3,2,1,0,7],
# [4,16,8,5,2,1,16,14,11,4,1,0,6,6,3,2,0,0,1],
# [12,19,12,3,1,0,22,15,8,2,0,0,3,1,2,0,0,0,0]])

A =np.array([
    [0,0,3,1,0,0,7,10,12,5,1,0,9,14,9,8,19,31,10],
    [0,0,3,1,0,0,7,10,12,5,1,0,9,14,9,8,3,8,10],
    [0,0,3,1,0,0,7,10,12,5,1,0,9,14,9,8,3,8,10]
            ])
print(len(A[0])
plt.figure(dpi=360)
ax = sns.heatmap(A, vmin=0,vmax=25,annot=True, fmt="d",annot_kws={"size":14},linewidths=0.1,cmap="BuPu")

# y = [6.5,5.5,4.5,3.5,2.5,1.5,0.5]

y = [2.5,1.5,0.5]

# labels = ['Regular 4G', 'Good 4G', 'Regular 5G', 'Good 5G', 'WiFi-6','WiFi-5GHz','WiFi-2.4GHz']

labels = ['WiFi','4G-Good','4G-Bad']


# #x = [0.5,1.5,2.5,3.5,4.5]
# xlabels = ["<10x-1/30>","<10x-1/29>","<10x-1/28>","<10x-1/27>","<10x-1/26>","<10x-1/25>","<10x-1/24>","<10x-1/23>","<10x-1/22>","<10x-1/21>",
# "<10x-1/20>","<10x-1/19>","<10x-1/18>","<10x-1/17>","<10x-1/16>","<10x-1/15>","<10x-1/14>","<10x-1/13>","<10x-1/12>","<10x-1/11>",
# "<10x-1/10>","<10x-1/9>","<10x-1/8>","<10x-1/7>","<10x-1/6>","<10x-1/5>","<10x-1/4>","<10x-1/3>","<10x-1/2>","<10x-1/1>",

# "<6x-1/30>","<6x-1/29>","<6x-1/28>","<6x-1/27>","<6x-1/26>","<6x-1/25>","<6x-1/24>","<6x-1/23>","<6x-1/22>","<6x-1/21>",
# "<6x-1/20>","<6x-1/19>","<6x-1/18>","<6x-1/17>","<6x-1/16>","<6x-1/15>","<6x-1/14>","<6x-1/13>","<6x-1/12>","<6x-1/11>",
# "<6x-1/10>","<6x-1/9>","<6x-1/8>","<6x-1/7>","<6x-1/6>","<6x-1/5>","<6x-1/4>","<6x-1/3>","<6x-1/2>","<6x-1/1>",

# "<4x-1/30>","<4x-1/29>","<4x-1/28>","<4x-1/27>","<4x-1/26>","<4x-1/25>","<4x-1/24>","<4x-1/23>","<4x-1/22>","<4x-1/21>",
# "<4x-1/20>","<4x-1/19>","<4x-1/18>","<4x-1/17>","<4x-1/16>","<4x-1/15>","<4x-1/14>","<4x-1/13>","<4x-1/12>","<4x-1/11>",
# "<4x-1/10>","<4x-1/9>","<4x-1/8>","<4x-1/7>","<4x-1/6>","<4x-1/5>","<4x-1/4>","<4x-1/3>","<4x-1/2>","<4x-1/1>"
# ]

xlabels = ["<8x-8x-1/15~1/30>","<8x-8x-1/1~1/15>","<8x-6x-1/15~1/30>","<8x-6x-1/1~1/15>","<8x-4x-1/15~1/30>","<8x-4x-1/1~1/15>",
           "<6x-8x-1/15~1/30>","<6x-8x-1/1~1/15>","<6x-6x-1/15~1/30>","<6x-6x-1/1~1/15>","<6x-4x-1/15~1/30>","<6x-4x-1/1~1/15>",
           "<4x-8x-1/15~1/30>","<4x-8x-1/1~1/15>","<4x-6x-1/15~1/30>","<4x-6x-1/1~1/15>","<4x-4x-1/15~1/30>","<4x-4x-1/1~1/15>","No-action" ]


#plt.xticks(x, xlabels,fontsize=7)
plt.yticks(y, labels,fontsize=16)
ax.tick_params(axis='y', rotation=0)
plt.xticks(range(len(xlabels)),xlabels,rotation=80,fontsize=14)



#plt.savefig('E:/heatmap.pdf', dpi=300)
plt.show()
# Out:
#   File "<ipython-input-122-82f2e7363da5>", line 21
#     plt.figure(dpi=360)
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()

# A =np.array([[2,11,9,3,0,1,14,14,15,7,2,0,6,7,3,2,0,2,2],
# [0,0,3,1,0,0,7,10,12,5,1,0,9,14,9,8,3,8,10],
# [0,0,2,0,0,0,6,9,12,3,0,0,12,18,15,5,2,7,9],
# [0,0,0,0,0,0,5,10,13,2,0,0,15,17,16,3,2,0,17],
# [0,0,3,0,1,0,13,19,17,7,0,0,13,14,3,2,1,0,7],
# [4,16,8,5,2,1,16,14,11,4,1,0,6,6,3,2,0,0,1],
# [12,19,12,3,1,0,22,15,8,2,0,0,3,1,2,0,0,0,0]])

A =np.array([
    [9,12,13,3,3,9,7,15,16,8,12,11,20,3,19,10,17,8,10,11,12,17,4,10,2,14,9,18],
    [11,3,2,9,5,15,7,0,14,7,14,1,0,13,5,2,12,11,8,7,7,11,11,5,0,3,0,14],
    [0,2,1,2,0,6,2,5,5,2,6,4,3,6,4,5,5,0,6,1,4,1,2,3,6,4,0,6]
            ])
plt.figure(figsize=(10, 5),dpi=300)
ax = sns.heatmap(A, vmin=0,vmax=25,annot=True, fmt="d",annot_kws={"size":16},linewidths=0.1,cmap="BuPu")

# y = [6.5,5.5,4.5,3.5,2.5,1.5,0.5]

y = [2.5,1.5,0.5]

# labels = ['Regular 4G', 'Good 4G', 'Regular 5G', 'Good 5G', 'WiFi-6','WiFi-5GHz','WiFi-2.4GHz']

labels = ['WiFi','4G-Good','4G-Bad']


# #x = [0.5,1.5,2.5,3.5,4.5]
# xlabels = ["<10x-1/30>","<10x-1/29>","<10x-1/28>","<10x-1/27>","<10x-1/26>","<10x-1/25>","<10x-1/24>","<10x-1/23>","<10x-1/22>","<10x-1/21>",
# "<10x-1/20>","<10x-1/19>","<10x-1/18>","<10x-1/17>","<10x-1/16>","<10x-1/15>","<10x-1/14>","<10x-1/13>","<10x-1/12>","<10x-1/11>",
# "<10x-1/10>","<10x-1/9>","<10x-1/8>","<10x-1/7>","<10x-1/6>","<10x-1/5>","<10x-1/4>","<10x-1/3>","<10x-1/2>","<10x-1/1>",

# "<6x-1/30>","<6x-1/29>","<6x-1/28>","<6x-1/27>","<6x-1/26>","<6x-1/25>","<6x-1/24>","<6x-1/23>","<6x-1/22>","<6x-1/21>",
# "<6x-1/20>","<6x-1/19>","<6x-1/18>","<6x-1/17>","<6x-1/16>","<6x-1/15>","<6x-1/14>","<6x-1/13>","<6x-1/12>","<6x-1/11>",
# "<6x-1/10>","<6x-1/9>","<6x-1/8>","<6x-1/7>","<6x-1/6>","<6x-1/5>","<6x-1/4>","<6x-1/3>","<6x-1/2>","<6x-1/1>",

# "<4x-1/30>","<4x-1/29>","<4x-1/28>","<4x-1/27>","<4x-1/26>","<4x-1/25>","<4x-1/24>","<4x-1/23>","<4x-1/22>","<4x-1/21>",
# "<4x-1/20>","<4x-1/19>","<4x-1/18>","<4x-1/17>","<4x-1/16>","<4x-1/15>","<4x-1/14>","<4x-1/13>","<4x-1/12>","<4x-1/11>",
# "<4x-1/10>","<4x-1/9>","<4x-1/8>","<4x-1/7>","<4x-1/6>","<4x-1/5>","<4x-1/4>","<4x-1/3>","<4x-1/2>","<4x-1/1>"
# ]

xlabels = ["<8x-8x-1/20~1/30>","<8x-8x-1/10~1/20>","<8x-8x-10/1~1/10>","<8x-6x-1/20~1/30>","<8x-6x-1/10~1/20>","<8x-6x-1/1~1/10>","<8x-4x-1/20~1/30>","<8x-4x-1/10~1/20>","<8x-4x-1/1~1/10>",
           "<6x-8x-1/20~1/30>","<6x-8x-1/10~1/20>","<6x-8x-10/1~1/10>","<6x-6x-1/20~1/30>","<6x-6x-1/10~1/20>","<6x-6x-1/1~1/10>","<6x-4x-1/20~1/30>","<8x-4x-1/10~1/20>","<6x-4x-1/1~1/10>",
           "<4x-8x-1/20~1/30>","<4x-8x-1/10~1/20>","<4x-8x-10/1~1/10>","<4x-6x-1/20~1/30>","<4x-6x-1/10~1/20>","<4x-6x-1/1~1/10>","<4x-4x-1/20~1/30>","<8x-4x-1/10~1/20>","<4x-4x-1/1~1/10>","No-action" ]


#plt.xticks(x, xlabels,fontsize=7)
plt.yticks(y, labels,fontsize=16)
ax.tick_params(axis='y', rotation=0)
plt.xticks(range(len(xlabels)),xlabels,rotation=80,fontsize=14)
plt.subplots_adjust(bottom=0.4) 
plt.savefig('E:/研学/绘图/me/heatmap.pdf',  bbox_inches='tight',dpi=300)
plt.show()

# %%
import random
import pandas as pd
A=[]
for i in range(100):
    b=random.randint(1, 20)
    a=random.randint(60, 120)
    A.append([b,a])
    
df = pd.DataFrame(A, columns=list(['TI','SI']))
df.to_excel("E:/研学/实验数据/SITI随机生成数据.xlsx", index=False)

A
# Out:
# [[10, 111],
#  [8, 98],
#  [10, 90],
#  [19, 93],
#  [9, 73],
#  [9, 90],
#  [13, 108],
#  [11, 80],
#  [5, 101],
#  [16, 109],
#  [3, 80],
#  [7, 96],
#  [9, 79],
#  [14, 89],
#  [16, 65],
#  [20, 104],
#  [2, 64],
#  [7, 68],
#  [20, 112],
#  [1, 67],
#  [6, 97],
#  [4, 88],
#  [17, 117],
#  [9, 75],
#  [11, 112],
#  [7, 81],
#  [3, 78],
#  [18, 112],
#  [15, 105],
#  [9, 66],
#  [14, 118],
#  [1, 67],
#  [14, 113],
#  [11, 82],
#  [20, 76],
#  [1, 99],
#  [19, 93],
#  [13, 106],
#  [12, 66],
#  [20, 71],
#  [20, 83],
#  [6, 95],
#  [5, 96],
#  [9, 67],
#  [9, 72],
#  [16, 83],
#  [18, 95],
#  [1, 91],
#  [4, 118],
#  [17, 107],
#  [5, 69],
#  [14, 112],
#  [9, 110],
#  [5, 91],
#  [19, 86],
#  [19, 77],
#  [2, 82],
#  [15, 120],
#  [20, 91],
#  [17, 109],
#  [13, 107],
#  [20, 75],
#  [2, 82],
#  [14, 90],
#  [16, 75],
#  [6, 91],
#  [6, 96],
#  [5, 86],
#  [13, 64],
#  [7, 104],
#  [17, 107],
#  [5, 106],
#  [17, 63],
#  [11, 85],
#  [6, 84],
#  [13, 91],
#  [1, 104],
# ...
